# %% [markdown]
# # MMTC Webscrape

# %%
# import libraries
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import numpy as np
from pprint import pprint

# %%
# launch browser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = 'https://knowthefactsmmj.com/mmtc/'
browser.visit(url)

# %%
# create Beautiful Soup object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## Dispensary Centers

# %%
# extract dispensary center table
table = soup.find('table', id='approveddispensing441')

# %%
# extract table headers

# extract table header row by extracting the first row
header_row = table.find('tr')

# extract header text
header_names = [header.find('span').text.strip() for header in header_row.find_all('td')]

# %%
# confirm data collection
print(header_names)
# Out:
# ['Name', 'Phone', 'Email', 'Authorization Status', 'License Number']

# %%
# extract table data

#exclude the first row (header row)
data_rows = table.find_all('tr')[1:]

#row_cells = [row.find_all('td') for row in data_rows]
#row_data = [cell.text.strip() for cell in row_cells]

row_data = [[cell.text.strip() for cell in row.find_all('td')] for row in data_rows]

# %%
# confirm data collection
pprint(row_data)
# Out:
# [['Ayr Cannabis Dispensary',
#   '833-254-4877',
#   'Info@libertyhealthsciences.com',
#   'Dispensing Authorization',
#   'MMTC-2015-0002'],
#  ['Cannabist',
#   '800-714-9215',
#   'info@col-carefl.com',
#   'Dispensing Authorization',
#   'MMTC-2017-0011'],
#  ['Cookies Florida, Inc.',
#   'n/a',
#   'n/a',
#   'Dispensing Authorization',
#   'MMTC-2019-0018'],
#  ['Curaleaf',
#   '877-303-0741',
#   'info.fl@curaleaf.com',
#   'Dispensing Authorization',
#   'MMTC-2015-0001'],
#  ['FLUENT',
#   '833-735-8368',
#   'info@getfluent.com',
#   'Dispensing Authorization',
#   'MMTC-2015-0003'],
#  ['Gold Leaf', 'n/a', 'n/a', 'Dispensing Authorization', 'MMTC-2019-0019'],
#  ['Green Dragon',
#   '720-600-9555',
#   'support@greendragon.com',
#   'Dispensing Authorization',
#   'MMTC-2019-0021'],
#  ['GrowHealthy',
#   '863-223-8882',
#   'info@GrowHealthy.com',
#   'Dispensing Authorization',
#   'MMTC-2016-0007'],
#  ['GTI (Rise Dispensaries)',
#   '305-306-8772',
#   'FLinfo@gtigrows.com',
#   'Dispensing Authorization',
#   'MMTC-2017-0013'],
#  ['House of Platinum Cannabis',
#   'n/a',
#   'n/a',
#   'Dispensing Authorization',
#   'MMTC-2018-0014'],
#  ['Insa - Cannabis for Real Life',
#   '413-200-5100',
#   'pat@myinsa.com',
#   'Dispensing Authorization',
#   'MMTC-2019-0016'],
#  ['Jungle Boys', 'n/a', 'n/a', 'Dispensing Authorization', 'MMTC-2019-0015'],
#  ['MüV',
#   '833-880-5420',
#   'support@muvbrand.com',
#   'Dispensing Authorization',
#   'MMTC-2017-0010'],
#  ['Planet 13 Florida, Inc.',
#   'n/a',
#   'n/a',
#   'Dispensing Authorization',
#   'MMTC-2016-0006'],
#  ['Revolution Florida',
#   'n/a',
#   'n/a',
#   'Dispensing Authorization',
#   'MMTC-2019-0022'],
#  ['Sanctuary Cannabis',
#   'n/a',
#   'n/a',
#   'Dispensing Authorization',
#   'MMTC-2019-0017'],
#  ['Shedrick McGriff', 'n/a', 'n/a', 'Initial Licensure', 'MMTC-2023-0024'],
#  ['Sunburn',
#   '786-288-3145',
#   'info.fldelivery@medmen.com',
#   'Dispensing Authorization',
#   'MMTC-2017-0012'],
#  ['Sunnyside*',
#   '877-395-1009',
#   'info@sunnyside.shop',
#   'Dispensing Authorization',
#   'MMTC-2017-0008'],
#  ['Surterra Wellness',
#   '850-391-5455',
#   'wellness@surterra.com',
#   'Dispensing Authorization',
#   'MMTC-2015-0004'],
#  ['Terry Donell Gwinn', 'n/a', 'n/a', 'Initial Licensure', 'MMTC-2023-0023'],
#  ['The Flowery',
#   '305-912-2929',
#   'Hello@theFlowery.co',
#   'Dispensing Authorization',
#   'MMTC-2019-0020'],
#  ['Trulieve',
#   '844-878-5438',
#   'info@trulieve.com',
#   'Dispensing Authorization',
#   'MMTC-2015-0005'],
#  ['VidaCann',
#   '800-977-1686',
#   'info@vidacann.com',
#   'Dispensing Authorization',
#   'MMTC-2017-0009']]

# %%
# import data into a dataframe

df_companies = pd.DataFrame(row_data, columns=header_names)

df_companies
# Out:
#                              Name         Phone  \
# 0         Ayr Cannabis Dispensary  833-254-4877
# 1                       Cannabist  800-714-9215
# 2           Cookies Florida, Inc.           n/a
# 3                        Curaleaf  877-303-0741
# 4                          FLUENT  833-735-8368
# 5                       Gold Leaf           n/a
# 6                    Green Dragon  720-600-9555
# 7                     GrowHealthy  863-223-8882
# 8         GTI (Rise Dispensaries)  305-306-8772
# 9      House of Platinum Cannabis           n/a
# 10  Insa - Cannabis for Real Life  413-200-5100
# 11                    Jungle Boys           n/a
# 12                            MüV  833-880-5420
# 13        Planet 13 Florida, Inc.           n/a
# 14             Revolution Florida           n/a
# 15             Sanctuary Cannabis           n/a
# 16               Shedrick McGriff           n/a
# 17                        Sunburn  786-288-3145
# 18                     Sunnyside*  877-395-1009
# 19              Surterra Wellness  850-391-5455
# 20             Terry Donell Gwinn           n/a
# 21                    The Flowery  305-912-2929
# 22                       Trulieve  844-878-5438
# 23                       VidaCann  800-977-1686
#
#                              Email      Authorization Status  License Number
# 0   Info@libertyhealthsciences.com  Dispensing Authorization  MMTC-2015-0002
# 1              info@col-carefl.com  Dispensing Authorization  MMTC-2017-0011
# 2                              n/a  Dispensing Authorization  MMTC-2019-0018
# 3             info.fl@curaleaf.com  Dispensing Authorization  MMTC-2015-0001
# 4               info@getfluent.com  Dispensing Authorization  MMTC-2015-0003
# 5                              n/a  Dispensing Authorization  MMTC-2019-0019
# 6          support@greendragon.com  Dispensing Authorization  MMTC-2019-0021
# 7             info@GrowHealthy.com  Dispensing Authorization  MMTC-2016-0007
# 8              FLinfo@gtigrows.com  Dispensing Authorization  MMTC-2017-0013
# 9                              n/a  Dispensing Authorization  MMTC-2018-0014
# 10                  pat@myinsa.com  Dispensing Authorization  MMTC-2019-0016
# 11                             n/a  Dispensing Authorization  MMTC-2019-0015
# 12            support@muvbrand.com  Dispensing Authorization  MMTC-2017-0010
# 13                             n/a  Dispensing Authorization  MMTC-2016-0006
# 14                             n/a  Dispensing Authorization  MMTC-2019-0022
# 15                             n/a  Dispensing Authorization  MMTC-2019-0017
# 16                             n/a         Initial Licensure  MMTC-2023-0024
# 17      info.fldelivery@medmen.com  Dispensing Authorization  MMTC-2017-0012
# 18             info@sunnyside.shop  Dispensing Authorization  MMTC-2017-0008
# 19           wellness@surterra.com  Dispensing Authorization  MMTC-2015-0004
# 20                             n/a         Initial Licensure  MMTC-2023-0023
# 21             Hello@theFlowery.co  Dispensing Authorization  MMTC-2019-0020
# 22               info@trulieve.com  Dispensing Authorization  MMTC-2015-0005
# 23               info@vidacann.com  Dispensing Authorization  MMTC-2017-0009

# %%
# change all n/a values to null
df_companies.replace('n/a', np.nan, inplace=True)

# renaming
df_companies.replace('MüV', 'MuV', inplace=True)
df_companies.replace('Sunnyside*', 'Sunnyside', inplace=True)


df_companies
# Out:
#                              Name         Phone  \
# 0         Ayr Cannabis Dispensary  833-254-4877
# 1                       Cannabist  800-714-9215
# 2           Cookies Florida, Inc.           NaN
# 3                        Curaleaf  877-303-0741
# 4                          FLUENT  833-735-8368
# 5                       Gold Leaf           NaN
# 6                    Green Dragon  720-600-9555
# 7                     GrowHealthy  863-223-8882
# 8         GTI (Rise Dispensaries)  305-306-8772
# 9      House of Platinum Cannabis           NaN
# 10  Insa - Cannabis for Real Life  413-200-5100
# 11                    Jungle Boys           NaN
# 12                            MuV  833-880-5420
# 13        Planet 13 Florida, Inc.           NaN
# 14             Revolution Florida           NaN
# 15             Sanctuary Cannabis           NaN
# 16               Shedrick McGriff           NaN
# 17                        Sunburn  786-288-3145
# 18                      Sunnyside  877-395-1009
# 19              Surterra Wellness  850-391-5455
# 20             Terry Donell Gwinn           NaN
# 21                    The Flowery  305-912-2929
# 22                       Trulieve  844-878-5438
# 23                       VidaCann  800-977-1686
#
#                              Email      Authorization Status  License Number
# 0   Info@libertyhealthsciences.com  Dispensing Authorization  MMTC-2015-0002
# 1              info@col-carefl.com  Dispensing Authorization  MMTC-2017-0011
# 2                              NaN  Dispensing Authorization  MMTC-2019-0018
# 3             info.fl@curaleaf.com  Dispensing Authorization  MMTC-2015-0001
# 4               info@getfluent.com  Dispensing Authorization  MMTC-2015-0003
# 5                              NaN  Dispensing Authorization  MMTC-2019-0019
# 6          support@greendragon.com  Dispensing Authorization  MMTC-2019-0021
# 7             info@GrowHealthy.com  Dispensing Authorization  MMTC-2016-0007
# 8              FLinfo@gtigrows.com  Dispensing Authorization  MMTC-2017-0013
# 9                              NaN  Dispensing Authorization  MMTC-2018-0014
# 10                  pat@myinsa.com  Dispensing Authorization  MMTC-2019-0016
# 11                             NaN  Dispensing Authorization  MMTC-2019-0015
# 12            support@muvbrand.com  Dispensing Authorization  MMTC-2017-0010
# 13                             NaN  Dispensing Authorization  MMTC-2016-0006
# 14                             NaN  Dispensing Authorization  MMTC-2019-0022
# 15                             NaN  Dispensing Authorization  MMTC-2019-0017
# 16                             NaN         Initial Licensure  MMTC-2023-0024
# 17      info.fldelivery@medmen.com  Dispensing Authorization  MMTC-2017-0012
# 18             info@sunnyside.shop  Dispensing Authorization  MMTC-2017-0008
# 19           wellness@surterra.com  Dispensing Authorization  MMTC-2015-0004
# 20                             NaN         Initial Licensure  MMTC-2023-0023
# 21             Hello@theFlowery.co  Dispensing Authorization  MMTC-2019-0020
# 22               info@trulieve.com  Dispensing Authorization  MMTC-2015-0005
# 23               info@vidacann.com  Dispensing Authorization  MMTC-2017-0009

# %% [markdown]
# ## Dispensary Locations

# %%
# extract dispensary locations table
table = soup.find('table', id='DataTables_Table_0')

# %%
# extract table headers
header_row = table.find('thead')
header_names = [header.text.strip() for header in header_row.find_all('th')]

# %%
# confirm data collection
print(header_names)
# Out:
# ['COMPANY', 'ADDRESS', 'EMAIL ADDRESS', 'PHONE', 'CITY', 'ZIP CODE', 'COUNTY']

# %%
# extract table data
data = table.find('tbody')
data_rows = data.find_all('tr')

row_data = [[cell.text.strip() for cell in row.find_all('td')] for row in data_rows]

# %%
# confirm data collection
pprint(row_data)
# Out:
# [['Ayr Cannabis Dispensary',
#   '6325 N Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32810',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '7390 Aloma Avenue',
#   '-',
#   '-',
#   'Winter Park',
#   '32792',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '4650 N Alafaya Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32826',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '440 N State Road 19',
#   '-',
#   '-',
#   'Palatka',
#   '32177',
#   'Putnam'],
#  ['Ayr Cannabis Dispensary',
#   '6930 Cypress Gardens Boulevard',
#   '-',
#   '-',
#   'Winter Haven',
#   '33884',
#   'Polk'],
#  ['Ayr Cannabis Dispensary',
#   '13832 Landstar Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32824',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '3701 W Lake Mary Boulevard',
#   '-',
#   '-',
#   'Lake Mary',
#   '32746',
#   'Seminole'],
#  ['Ayr Cannabis Dispensary',
#   '8898 SW 144th Terrace',
#   '-',
#   '-',
#   'Palmetto Bay',
#   '33158',
#   'Miami-Dade'],
#  ['Ayr Cannabis Dispensary',
#   '21529 Village Lakes Shopping Center Drive',
#   '-',
#   '-',
#   'Land O’ Lakes',
#   '34639',
#   'Pasco'],
#  ['Ayr Cannabis Dispensary',
#   '7720 Turkey Lake Road',
#   '-',
#   '-',
#   'Orlando',
#   '32819',
#   'Orange']]

# %%
# extract table data

# find table pages
pagination = soup.find('div', id='DataTables_Table_0_paginate')
pagination_buttons = pagination.find_all('a')
last_page_button = pagination_buttons[-2]
last_page = int(last_page_button.text)+1

row_data = []

# loop through all table pages
for x in range(1, last_page):
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', id='DataTables_Table_0')
    table_data = table.find('tbody')
    data_rows = table_data.find_all('tr')
    row_data.extend([[cell.text.strip() for cell in row.find_all('td')] for row in data_rows])

    # go to next page
    browser.links.find_by_partial_text('Next').click()

# %%
# confirm data collection
pprint(row_data)
# Out:
# [['Ayr Cannabis Dispensary',
#   '6325 N Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32810',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '7390 Aloma Avenue',
#   '-',
#   '-',
#   'Winter Park',
#   '32792',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '4650 N Alafaya Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32826',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '440 N State Road 19',
#   '-',
#   '-',
#   'Palatka',
#   '32177',
#   'Putnam'],
#  ['Ayr Cannabis Dispensary',
#   '6930 Cypress Gardens Boulevard',
#   '-',
#   '-',
#   'Winter Haven',
#   '33884',
#   'Polk'],
#  ['Ayr Cannabis Dispensary',
#   '13832 Landstar Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32824',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '3701 W Lake Mary Boulevard',
#   '-',
#   '-',
#   'Lake Mary',
#   '32746',
#   'Seminole'],
#  ['Ayr Cannabis Dispensary',
#   '8898 SW 144th Terrace',
#   '-',
#   '-',
#   'Palmetto Bay',
#   '33158',
#   'Miami-Dade'],
#  ['Ayr Cannabis Dispensary',
#   '21529 Village Lakes Shopping Center Drive',
#   '-',
#   '-',
#   'Land O’ Lakes',
#   '34639',
#   'Pasco'],
#  ['Ayr Cannabis Dispensary',
#   '7720 Turkey Lake Road',
#   '-',
#   '-',
#   'Orlando',
#   '32819',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '41680 US Hwy 19 N',
#   '-',
#   '-',
#   'Tarpon Springs',
#   '34689',
#   'Pinellas'],
#  ['Ayr Cannabis Dispensary',
#   '7118 S Military Trail',
#   '-',
#   '-',
#   'Lake Worth',
#   '33463',
#   'Palm Beach'],
#  ['Ayr Cannabis Dispensary',
#   '2290 W International Speedway Boulevard',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Ayr Cannabis Dispensary',
#   '222 N Federal Highway, Suite 103',
#   '-',
#   '-',
#   'Dania Beach',
#   '33004',
#   'Broward'],
#  ['Ayr Cannabis Dispensary',
#   '8050 Philips Highway',
#   '-',
#   '-',
#   'Jacksonville',
#   '32217',
#   'Duval'],
#  ['Ayr Cannabis Dispensary',
#   '314 S Belcher Road',
#   '-',
#   '-',
#   'Clearwater',
#   '33765',
#   'Pinellas'],
#  ['Ayr Cannabis Dispensary',
#   '750 S US Hwy 17-92',
#   '-',
#   '-',
#   'Longwood',
#   '32750',
#   'Seminole'],
#  ['Ayr Cannabis Dispensary',
#   '900 Hooks Street',
#   '-',
#   '-',
#   'Clermont',
#   '34714',
#   'Lake'],
#  ['Ayr Cannabis Dispensary',
#   '5502 S Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33611',
#   'Hillsborough'],
#  ['Ayr Cannabis Dispensary',
#   '3642 W Kennedy Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33609',
#   'Hillsborough'],
#  ['Ayr Cannabis Dispensary',
#   '6769 US Hwy 19 N',
#   '-',
#   '-',
#   'Pinellas Park',
#   '33781',
#   'Pinellas'],
#  ['Ayr Cannabis Dispensary',
#   '15443 US Hwy 441',
#   '-',
#   '-',
#   'Eustis',
#   '32726',
#   'Lake'],
#  ['Ayr Cannabis Dispensary',
#   '9304 US Hwy 19 N',
#   '-',
#   '-',
#   'Port Richey',
#   '34668',
#   'Pasco'],
#  ['Ayr Cannabis Dispensary',
#   '2146 W 9 Mile Road',
#   '-',
#   '-',
#   'Pensacola',
#   '32534',
#   'Escambia'],
#  ['Ayr Cannabis Dispensary',
#   '1865 Woolbright Road',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33426',
#   'Palm Beach'],
#  ['Ayr Cannabis Dispensary',
#   '4920 E Silver Springs Boulevard',
#   '-',
#   '-',
#   'Ocala',
#   '34470',
#   'Marion'],
#  ['Ayr Cannabis Dispensary',
#   '2119-A Hollywood Boulevard',
#   '-',
#   '-',
#   'Hollywood',
#   '33020',
#   'Broward'],
#  ['Ayr Cannabis Dispensary',
#   '2356 Commercial Way Service Road',
#   '-',
#   '-',
#   'Spring Hill',
#   '34606',
#   'Hernando'],
#  ['Ayr Cannabis Dispensary',
#   '826 Duval Street',
#   '-',
#   '-',
#   'Key West',
#   '33040',
#   'Monroe'],
#  ['Ayr Cannabis Dispensary',
#   '33497 S Dixie Highway',
#   '-',
#   '-',
#   'Florida City',
#   '33034',
#   'Miami-Dade'],
#  ['Ayr Cannabis Dispensary',
#   '421 Mary Esther Boulevard',
#   '-',
#   '-',
#   'Mary Esther',
#   '32569',
#   'Okaloosa'],
#  ['Ayr Cannabis Dispensary',
#   '135 US Hwy 27 N',
#   '-',
#   '-',
#   'Sebring',
#   '33870',
#   'Highlands'],
#  ['Ayr Cannabis Dispensary',
#   '4805 Babcock Street NE',
#   '-',
#   '-',
#   'Palm Bay',
#   '32905',
#   'Brevard'],
#  ['Ayr Cannabis Dispensary',
#   '5053 Turnpike Feeder Road',
#   '-',
#   '-',
#   'Fort Pierce',
#   '34951',
#   'St. Lucie'],
#  ['Ayr Cannabis Dispensary',
#   '4656 Tamiami Trail',
#   '-',
#   '-',
#   'Port Charlotte',
#   '33980',
#   'Charlotte'],
#  ['Ayr Cannabis Dispensary',
#   '8951 Daniels Parkway',
#   '-',
#   '-',
#   'Fort Myers',
#   '33912',
#   'Lee'],
#  ['Ayr Cannabis Dispensary',
#   '1720 W US Hwy 90',
#   '-',
#   '-',
#   'Lake City',
#   '32055',
#   'Columbia'],
#  ['Ayr Cannabis Dispensary',
#   '2198 A1A S',
#   '-',
#   '-',
#   'St. Augustine Beach',
#   '32080',
#   'St. Johns'],
#  ['Ayr Cannabis Dispensary',
#   '1222 S 3rd Street',
#   '-',
#   '-',
#   'Jacksonville Beach',
#   '32250',
#   'Duval'],
#  ['Ayr Cannabis Dispensary',
#   '3323 SE Federal Highway',
#   '-',
#   '-',
#   'Stuart',
#   '32997',
#   'Martin'],
#  ['Ayr Cannabis Dispensary',
#   '1540 Palm Beach Lakes Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['Ayr Cannabis Dispensary',
#   '6990 Florida Avenue S',
#   '-',
#   '-',
#   'Lakeland',
#   '33813',
#   'Polk'],
#  ['Ayr Cannabis Dispensary',
#   '1475 Cortez Road',
#   '-',
#   '-',
#   'Bradenton',
#   '34207',
#   'Manatee'],
#  ['Ayr Cannabis Dispensary',
#   '9815 S Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32837',
#   'Orange'],
#  ['Ayr Cannabis Dispensary',
#   '2067 Siesta Drive',
#   '-',
#   '-',
#   'Sarasota',
#   '34239',
#   'Sarasota'],
#  ['Ayr Cannabis Dispensary',
#   '2814 W Martin Luther King Jr. Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33607',
#   'Hillsborough'],
#  ['Ayr Cannabis Dispensary',
#   '7152 N Davis Highway',
#   '-',
#   '-',
#   'Pensacola',
#   '32504',
#   'Escambia'],
#  ['Ayr Cannabis Dispensary',
#   '809 Harrison Avenue',
#   '-',
#   '-',
#   'Panama City',
#   '32401',
#   'Bay'],
#  ['Ayr Cannabis Dispensary',
#   '9912 Glades Road',
#   '-',
#   '-',
#   'Boca Raton',
#   '33434',
#   'Palm Beach'],
#  ['Ayr Cannabis Dispensary',
#   '635 W Tennessee Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32304',
#   'Leon'],
#  ['Ayr Cannabis Dispensary',
#   '1321 SE 47th Terrace',
#   '-',
#   '-',
#   'Cape Coral',
#   '33904',
#   'Lee'],
#  ['Ayr Cannabis Dispensary',
#   '24611 Production Circle',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Ayr Cannabis Dispensary',
#   '12 SW 2nd Street',
#   '-',
#   '-',
#   'Gainesville',
#   '32601',
#   'Alachua'],
#  ['Ayr Cannabis Dispensary',
#   '1907 Wells Road',
#   '-',
#   '-',
#   'Orange Park',
#   '32073',
#   'Clay'],
#  ['Ayr Cannabis Dispensary',
#   '10755 Biscayne Boulevard',
#   '-',
#   '-',
#   'Miami',
#   '33161',
#   'Miami-Dade'],
#  ['Ayr Cannabis Dispensary',
#   '6827 SW 40th Street',
#   '-',
#   '-',
#   'Miami',
#   '33155',
#   'Miami-Dade'],
#  ['Ayr Cannabis Dispensary',
#   '31487 US Hwy 19 N',
#   '-',
#   '-',
#   'Palm Harbor',
#   '34684',
#   'Pinellas'],
#  ['Ayr Cannabis Dispensary',
#   '150 E Merritt Island Causeway',
#   '-',
#   '-',
#   'Merritt Island',
#   '32952',
#   'Brevard'],
#  ['Ayr Cannabis Dispensary',
#   '1285 1st Street',
#   '-',
#   '-',
#   'Winter Haven',
#   '33880',
#   'Polk'],
#  ['Ayr Cannabis Dispensary',
#   '16810 S Hwy 441',
#   '-',
#   '-',
#   'Summerfield',
#   '34491',
#   'Marion'],
#  ['Ayr Cannabis Dispensary',
#   '513 Martin Luther King Jr. Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33701',
#   'Pinellas'],
#  ['Ayr Cannabis Dispensary',
#   '10941 US Hwy 1',
#   '-',
#   '-',
#   'Port St. Lucie',
#   '34952',
#   'St. Lucie'],
#  ['Cannabist',
#   '6110 W Atlantic Avenue',
#   '-',
#   '-',
#   'Delray Beach',
#   '33484',
#   'Palm Beach'],
#  ['Cannabist',
#   '12079 SW 117th Avenue',
#   '-',
#   '-',
#   'Miami',
#   '33186',
#   'Miami-Dade'],
#  ['Cannabist',
#   '1415 W State Road 434',
#   '-',
#   '-',
#   'Longwood',
#   '32750',
#   'Seminole'],
#  ['Cannabist',
#   '2118 W Brandon Boulevard',
#   '-',
#   '-',
#   'Brandon',
#   '33511',
#   'Hillsborough'],
#  ['Cannabist', '4545 14th Street W', '-', '-', 'Bradenton', '34207', 'Manatee'],
#  ['Cannabist',
#   '4203 SE Federal Highway',
#   '-',
#   '-',
#   'Stuart',
#   '34997',
#   'Martin'],
#  ['Cannabist',
#   '8800 Terrene Court',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Cannabist',
#   '160 King Street',
#   '-',
#   '-',
#   'St. Augustine',
#   '32084',
#   'St. Johns'],
#  ['Cannabist', '21 Suntree Place', '-', '-', 'Melbourne', '32803', 'Brevard'],
#  ['Cannabist',
#   '10615 E Colonial Drive',
#   '-',
#   '-',
#   'Orlando',
#   '32803',
#   'Orange'],
#  ['Cannabist',
#   '2126 Del Prado Boulevard S',
#   '-',
#   '-',
#   'Cape Coral',
#   '32216',
#   'Lee'],
#  ['Cannabist',
#   '4332 University Boulevard S',
#   '-',
#   '-',
#   'Jacksonville',
#   '32216',
#   'Duval'],
#  ['Cannabist',
#   '6979 S Tamiami Trail',
#   '-',
#   '-',
#   'Sarasota',
#   '34231',
#   'Sarasota'],
#  ['Cannabist',
#   '318 NW 13th Street',
#   '-',
#   '-',
#   'Gainesville',
#   '32601',
#   'Alachua'],
#  ['Cookies', '626 NW 13th Street', '-', '-', 'Gainesville', '32601', 'Alachua'],
#  ['Cookies', '1345 Lee Road', '-', '-', 'Orlando', '32810', 'Orange'],
#  ['Cookies', '8303 SW 40th Street', '-', '-', 'Miami', '33155', 'Miami-Dade'],
#  ['Curaleaf',
#   '300 Clematis Street',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['Curaleaf',
#   '7875 Glades Road',
#   '-',
#   '-',
#   'Boca Raton',
#   '33434',
#   'Palm Beach'],
#  ['Curaleaf',
#   '19631 State Road 7',
#   '-',
#   '-',
#   'Boca Raton',
#   '33498',
#   'Palm Beach'],
#  ['Curaleaf', '1900 US Hwy 27 S', '-', '-', 'Clermont', '34711', 'Lake'],
#  ['Curaleaf',
#   '3540 Northlake Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33403',
#   'Palm Beach'],
#  ['Curaleaf',
#   '2121 W Tennessee Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32304',
#   'Leon'],
#  ['Curaleaf',
#   '550 Collins Avenue',
#   '-',
#   '-',
#   'Miami Beach',
#   '33139',
#   'Miami-Dade'],
#  ['Curaleaf',
#   '6600 International Drive',
#   '-',
#   '-',
#   'Orlando',
#   '32819',
#   'Orange'],
#  ['Curaleaf', '9268 SE Maricamp Road', '-', '-', 'Ocala', '34772', 'Marion'],
#  ['Curaleaf', '10612 Sheldon Road', '-', '-', 'Tampa', '33626', 'Hillsborough'],
#  ['Curaleaf',
#   '612 N Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33609',
#   'Hillsborough'],
#  ['Curaleaf',
#   '11311 University Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32817',
#   'Orange'],
#  ['Curaleaf',
#   '4227 Manatee Avenue E',
#   '-',
#   '-',
#   'Bradenton',
#   '34208',
#   'Manatee'],
#  ['Curaleaf',
#   '1930 S McCall Road',
#   '-',
#   '-',
#   'Englewood',
#   '34223',
#   'Charlotte'],
#  ['Curaleaf',
#   '2900 Country Club Lane',
#   '-',
#   '-',
#   'Pembroke Park',
#   '33009',
#   'Broward'],
#  ['Curaleaf',
#   '6899 N University Drive',
#   '-',
#   '-',
#   'Tamarac',
#   '33321',
#   'Broward'],
#  ['Curaleaf', '10289 Ulmerton Road', '-', '-', 'Largo', '33771', 'Pinellas'],
#  ['Curaleaf',
#   '13755 N Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33618',
#   'Hillsborough'],
#  ['Curaleaf',
#   '12125 SW 152nd Street',
#   '-',
#   '-',
#   'Miami',
#   '33177',
#   'Miami-Dade'],
#  ['Curaleaf',
#   '19416 Bruce B Downs Boulevard',
#   '-',
#   '-',
#   'Wesley Chapel',
#   '33647',
#   'Pasco'],
#  ['Curaleaf', '919 US Hwy 441', '-', '-', 'Lady Lake', '32159', 'Lake'],
#  ['Curaleaf', '1910 SE Federal Highway', '-', '-', 'Stuart', '34994', 'Martin'],
#  ['Curaleaf',
#   '4287 Mariner Boulevard',
#   '-',
#   '-',
#   'Spring Hill',
#   '34609',
#   'Hernando'],
#  ['Curaleaf',
#   '6835 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33411',
#   'Palm Beach'],
#  ['Curaleaf', '2605 Cortez Road W', '-', '-', 'Bradenton', '34207', 'Manatee'],
#  ['Curaleaf',
#   '5935 4th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33703',
#   'Pinellas'],
#  ['Curaleaf',
#   '9760 San Jose Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32257',
#   'Duval'],
#  ['Curaleaf',
#   '846 E Brandon Boulevard',
#   '-',
#   '-',
#   'Brandon',
#   '33511',
#   'Hillsborough'],
#  ['Curaleaf',
#   '3630 W Gandy Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33611',
#   'Hillsborough'],
#  ['Curaleaf',
#   '2082 Gulf to Bay Boulevard',
#   '-',
#   '-',
#   'Clearwater',
#   '33765',
#   'Pinellas'],
#  ['Curaleaf', '749 W 23rd Street', '-', '-', 'Panama City', '32405', 'Bay'],
#  ['Curaleaf', '5090 N 9th Avenue', '-', '-', 'Pensacola', '32504', 'Escambia'],
#  ['Curaleaf',
#   '1435 S Tamiami Trail',
#   '-',
#   '-',
#   'Sarasota',
#   '34239',
#   'Sarasota'],
#  ['Curaleaf',
#   '3631 NW Federal Highway',
#   '-',
#   '-',
#   'Jensen Beach',
#   '34957',
#   'Martin'],
#  ['Curaleaf',
#   '1994 Kings Highway',
#   '-',
#   '-',
#   'Port Charlotte',
#   '33980',
#   'Charlotte'],
#  ['Curaleaf',
#   '610 Lake Minnie Drive',
#   '-',
#   '-',
#   'Sanford',
#   '32771',
#   'Seminole'],
#  ['Curaleaf',
#   '495 Blanding Boulevard',
#   '-',
#   '-',
#   'Orange Park',
#   '32073',
#   'Clay'],
#  ['Curaleaf',
#   '2300 SW 34th Street',
#   '-',
#   '-',
#   'Gainesville',
#   '32607',
#   'Alachua'],
#  ['Curaleaf', '5400 NW 72nd Avenue', '-', '-', 'Miami', '33166', 'Miami-Dade'],
#  ['Curaleaf',
#   '11721 Bonita Beach Road',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Curaleaf',
#   '200 S Washington Avenue',
#   '-',
#   '-',
#   'Titusville',
#   '32796',
#   'Brevard'],
#  ['Curaleaf', '1408 Dale Mabry Highway', '-', '-', 'Lutz', '33548', 'Pasco'],
#  ['Curaleaf', '1839 SW College Road', '-', '-', 'Ocala', '34471', 'Marion'],
#  ['Curaleaf',
#   '6421 N Florida Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33604',
#   'Hillsborough'],
#  ['Curaleaf',
#   '1345 Thomasville Road',
#   '-',
#   '-',
#   'Tallahassee',
#   '32303',
#   'Leon'],
#  ['Curaleaf',
#   '775 N Semoran Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32807',
#   'Orange'],
#  ['Curaleaf',
#   '16685 NW 2nd Avenue',
#   '-',
#   '-',
#   'North Miami',
#   '33169',
#   'Miami-Dade'],
#  ['Curaleaf', '3218 US Hwy 1', '-', '-', 'Fort Pierce', '34982', 'St. Lucie'],
#  ['Curaleaf',
#   '910 W International Speedway Boulevard',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Curaleaf',
#   '148 N Federal Highway',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['Curaleaf', '3145 US Hwy 98 N', '-', '-', 'Lakeland', '33805', 'Polk'],
#  ['Curaleaf', '6361 103rd Street', '-', '-', 'Jacksonville', '32210', 'Duval'],
#  ['Curaleaf',
#   '12402 S Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32837',
#   'Orange'],
#  ['Curaleaf',
#   '3811 Tyrone Boulevard',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33709',
#   'Pinellas'],
#  ['Curaleaf',
#   '35388 US Hwy 19 N',
#   '-',
#   '-',
#   'Palm Harbor',
#   '34684',
#   'Pinellas'],
#  ['Curaleaf',
#   '1420 Palm Bay Road NE',
#   '-',
#   '-',
#   'Palm Bay',
#   '32905',
#   'Brevard'],
#  ['Curaleaf',
#   '19000 SW 192nd Street',
#   '-',
#   '-',
#   'Miami',
#   '33187',
#   'Miami-Dade'],
#  ['Curaleaf',
#   '1125 N Dixie Highway',
#   '-',
#   '-',
#   'Lake Worth',
#   '33460',
#   'Palm Beach'],
#  ['Curaleaf',
#   '9002 S Dadeland Boulevard',
#   '-',
#   '-',
#   'Kendall',
#   '33156',
#   'Miami-Dade'],
#  ['Curaleaf', '4480 Fowler Street', '-', '-', 'Fort Myers', '33901', 'Lee'],
#  ['FLUENT', '971 Cassat Avenue', '-', '-', 'Jacksonville', '32205', 'Duval'],
#  ['FLUENT',
#   '2385 S Ferdon Boulevard',
#   '-',
#   '-',
#   'Crestview',
#   '32536',
#   'Okaloosa'],
#  ['FLUENT', '500 E Chase Street', '-', '-', 'Pensacola', '32502', 'Escambia'],
#  ['FLUENT',
#   '763 Atlantic Boulevard',
#   '-',
#   '-',
#   'Atlantic Beach',
#   '32233',
#   'Duval'],
#  ['FLUENT', '301 E Nine Road', '-', '-', 'Pensacola', '32514', 'Escambia'],
#  ['FLUENT', '2090 U.S. 98', '-', '-', 'Mary Esther', '32569', 'Okaloosa'],
#  ['FLUENT', '3460 US Hwy 441', '-', '-', 'Fruitland Park', '34731', 'Lake'],
#  ['FLUENT',
#   '622 S Federal Highway',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['FLUENT', '9637 US Hwy 98', '-', '-', 'Miramar Beach', '32550', 'Walton'],
#  ['FLUENT', '2620 S US Hwy 1', '-', '-', 'Fort Pierce', '34982', 'St. Lucie'],
#  ['FLUENT', '9611 N Kendall Drive', '-', '-', 'Miami', '33176', 'Miami-Dade'],
#  ['FLUENT', '5827 SW 40th Street', '-', '-', 'Miami', '33155', 'Miami-Dade'],
#  ['FLUENT',
#   '1406 N University Drive',
#   '-',
#   '-',
#   'Coral Springs',
#   '33701',
#   'Broward'],
#  ['FLUENT', '10607 E Colonial Drive', '-', '-', 'Orlando', '32817', 'Orange'],
#  ['FLUENT', '3611 US Hwy 98', '-', '-', 'Panama City', '32401', 'Bay'],
#  ['FLUENT', '4825 US Hwy 98 N', '-', '-', 'Lakeland', '33809', 'Polk'],
#  ['FLUENT',
#   '9510 Atlantic Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32225',
#   'Duval'],
#  ['FLUENT',
#   '606 S Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33609',
#   'Hillsborough'],
#  ['FLUENT', '103 SW 3rd Place', '-', '-', 'Cape Coral', '33991', 'Lee'],
#  ['FLUENT',
#   '5138 Deer Park Drive',
#   '-',
#   '-',
#   'New Port Richey',
#   '34653',
#   'Pasco'],
#  ['FLUENT',
#   '5611 Six Mile Commercial Court',
#   '-',
#   '-',
#   'Fort Myers',
#   '33912',
#   'Lee'],
#  ['FLUENT', '11245 SW 211 Street', '-', '-', 'Miami', '33189', 'Miami-Dade'],
#  ['FLUENT', '6340 N Wickham Road', '-', '-', 'Melbourne', '32940', 'Brevard'],
#  ['FLUENT', '487 State Road 436', '-', '-', 'Casselberry', '32707', 'Seminole'],
#  ['FLUENT',
#   '921 S Missouri Avenue',
#   '-',
#   '-',
#   'Clearwater',
#   '33756',
#   'Pinellas'],
#  ['FLUENT',
#   '175 NW 167th Street',
#   '-',
#   '-',
#   'North Miami Beach',
#   '33169',
#   'Miami-Dade'],
#  ['FLUENT',
#   '601 34th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33713',
#   'Pinellas'],
#  ['FLUENT', '1901 N Orange Avenue', '-', '-', 'Orlando', '32804', 'Orange'],
#  ['FLUENT', '1 S Dixie Highway', '-', '-', 'Lake Worth', '33460', 'Palm Beach'],
#  ['FLUENT', '3400 SW 34th Street', '-', '-', 'Gainesville', '32608', 'Alachua'],
#  ['FLUENT',
#   '109 Racetrack Road NE',
#   '-',
#   '-',
#   'Fort Walton Beach',
#   '32547',
#   'Okaloosa'],
#  ['FLUENT',
#   '9901 San Jose Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32257',
#   'Duval'],
#  ['FLUENT', '1902 Thomasville Road', '-', '-', 'Tallahassee', '32303', 'Leon'],
#  ['Gold Leaf',
#   '5220 Hardware Place',
#   '-',
#   '-',
#   'Sebring',
#   '33870',
#   'Highlands'],
#  ['Green Dragon',
#   '15405 US Hwy 441',
#   '-',
#   '-',
#   'Summerfield',
#   '34491',
#   'Marion'],
#  ['Green Dragon',
#   '1170 S Broad Street',
#   '-',
#   '-',
#   'Brooksville',
#   '34601',
#   'Hernando'],
#  ['Green Dragon',
#   '91 NE US Hwy 19',
#   '-',
#   '-',
#   'Crystal River',
#   '34429',
#   'Citrus'],
#  ['Green Dragon', '1500 N US Hwy 41', '-', '-', 'Inverness', '34450', 'Citrus'],
#  ['Green Dragon',
#   '12605 Biscayne Boulevard',
#   '-',
#   '-',
#   'North Miami',
#   '33181',
#   'Miami-Dade'],
#  ['Green Dragon', '855 W Base Street', '-', '-', 'Madison', '32340', 'Madison'],
#  ['Green Dragon', '800 Lee Road', '-', '-', 'Orlando', '32810', 'Orange'],
#  ['Green Dragon',
#   '1271 Pasadena Avenue S',
#   '-',
#   '-',
#   'South Pasadena',
#   '33707',
#   'Pinellas'],
#  ['Green Dragon',
#   '2590 S Volusia Avenue',
#   '-',
#   '-',
#   'Orange City',
#   '32763',
#   'Volusia'],
#  ['Green Dragon',
#   '130 Fountain Parkway N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33716',
#   'Pinellas'],
#  ['Green Dragon',
#   '920 N Navy Boulevard',
#   '-',
#   '-',
#   'Pensacola',
#   '32507',
#   'Escambia'],
#  ['Green Dragon',
#   '5500 Bayshore Road',
#   '-',
#   '-',
#   'North Fort Myers',
#   '33917',
#   'Lee'],
#  ['Green Dragon',
#   '6352 103rd Street',
#   '-',
#   '-',
#   'Jacksonville',
#   '32210',
#   'Duval'],
#  ['Green Dragon',
#   '5180 Baymeadows Road',
#   '-',
#   '-',
#   'Jacksonville',
#   '32217',
#   'Duval'],
#  ['Green Dragon',
#   '917 Harrison Avenue',
#   '-',
#   '-',
#   'Panama City',
#   '32401',
#   'Bay'],
#  ['Green Dragon', '1403 Akron Drive', '-', '-', 'Leesburg', '34748', 'Lake'],
#  ['Green Dragon',
#   '1985 N Andrews Avenue',
#   '-',
#   '-',
#   'Wilton Manors',
#   '33311',
#   'Broward'],
#  ['Green Dragon',
#   '1001 S US Hwy 1',
#   '-',
#   '-',
#   'Fort Pierce',
#   '34950',
#   'St. Lucie'],
#  ['Green Dragon',
#   '895 N Summit Street',
#   '-',
#   '-',
#   'Crescent City',
#   '32112',
#   'Putnam'],
#  ['Green Dragon',
#   '950 Blanding Boulevard',
#   '-',
#   '-',
#   'Orange Park',
#   '32065',
#   'Clay'],
#  ['Green Dragon',
#   '1912 N Monroe Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32303',
#   'Leon'],
#  ['Green Dragon',
#   '437 W Gaines Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32301',
#   'Leon'],
#  ['Green Dragon',
#   '701 E 9 Mile Road',
#   '-',
#   '-',
#   'Pensacola',
#   '32514',
#   'Escambia'],
#  ['Green Dragon',
#   '1519 Saint Johns Avenue',
#   '-',
#   '-',
#   'Palatka',
#   '32177',
#   'Putnam'],
#  ['Green Dragon',
#   '2048 SE Federal Highway',
#   '-',
#   '-',
#   'Stuart',
#   '34994',
#   'Martin'],
#  ['Green Dragon',
#   '2645 E Silver Springs Boulevard',
#   '-',
#   '-',
#   'Ocala',
#   '34470',
#   'Marion'],
#  ['Green Dragon',
#   '714 Cheney Highway',
#   '-',
#   '-',
#   'Titusville',
#   '32780',
#   'Brevard'],
#  ['Green Dragon',
#   '205 Crockett Boulevard',
#   '-',
#   '-',
#   'Merritt Island',
#   '32953',
#   'Brevard'],
#  ['Green Dragon',
#   '12807 W Hillsborough Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33635',
#   'Hillsborough'],
#  ['Green Dragon',
#   '2201 S Federal Highway',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33435',
#   'Palm Beach'],
#  ['Green Dragon',
#   '1695 Forum Place',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['Green Dragon',
#   '7343 Lake Worth Road',
#   '-',
#   '-',
#   'Lake Worth',
#   '33467',
#   'Palm Beach'],
#  ['Green Dragon',
#   '1660 S Congress Avenue',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33426',
#   'Palm Beach'],
#  ['GrowHealthy',
#   '3974 W Linebaugh Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33618',
#   'Hillsborough'],
#  ['GrowHealthy', '3555 Clark Road', '-', '-', 'Sarasota', '34231', 'Sarasota'],
#  ['GrowHealthy',
#   '2323 Del Prado Boulevard',
#   '-',
#   '-',
#   'Cape Coral',
#   '33990',
#   'Lee'],
#  ['GrowHealthy', '4465 E Bay Drive', '-', '-', 'Largo', '33746', 'Pinellas'],
#  ['GrowHealthy',
#   '7817 N Davis Highway',
#   '-',
#   '-',
#   'Pensacola',
#   '32514',
#   'Escambia'],
#  ['GrowHealthy',
#   '1787 W Tennessee Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32304',
#   'Leon'],
#  ['GrowHealthy',
#   '1981 SE Federal Highway',
#   '-',
#   '-',
#   'Stuart',
#   '34994',
#   'Martin'],
#  ['GrowHealthy',
#   '1444 S Federal Highway',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['GrowHealthy', '2370 SW College Road', '-', '-', 'Ocala', '34474', 'Marion'],
#  ['GrowHealthy',
#   '25987 S Tamiami Trail',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34134',
#   'Lee'],
#  ['GrowHealthy',
#   '13400 Biscayne Boulevard',
#   '-',
#   '-',
#   'North Miami',
#   '33181',
#   'Miami-Dade'],
#  ['GrowHealthy',
#   '4880 Newberry Road',
#   '-',
#   '-',
#   'Gainesville',
#   '32607',
#   'Alachua'],
#  ['GrowHealthy', '3004 US Hwy 98 N', '-', '-', 'Lakeland', '33805', 'Polk'],
#  ['GrowHealthy',
#   '7858 Turkey Lake Road',
#   '-',
#   '-',
#   'Orlando',
#   '32819',
#   'Orange'],
#  ['GrowHealthy',
#   '2525 W International Speedway Boulevard',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['GrowHealthy',
#   '5614 State Road 7',
#   '-',
#   '-',
#   'Lake Worth',
#   '33449',
#   'Palm Beach'],
#  ['GrowHealthy',
#   '1525 E Brandon Boulevard',
#   '-',
#   '-',
#   'Brandon',
#   '33411',
#   'Hillsborough'],
#  ['GrowHealthy',
#   '4237 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['GTI (Rise Dispensaries)',
#   '3295 US Hwy 441',
#   '-',
#   '-',
#   'Fruitland Park',
#   '34731',
#   'Lake'],
#  ['GTI (Rise Dispensaries)',
#   '420 W Brandon Boulevard',
#   '-',
#   '-',
#   'Brandon',
#   '33511',
#   'Hillsborough'],
#  ['GTI (Rise Dispensaries)',
#   '11561 N Kendall Drive',
#   '-',
#   '-',
#   'Miami',
#   '33173',
#   'Miami-Dade'],
#  ['GTI (Rise Dispensaries)',
#   '430 Clematis Street',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33446',
#   'Palm Beach'],
#  ['GTI (Rise Dispensaries)',
#   '308 N Federal Highway',
#   '-',
#   '-',
#   'Hallandale Beach',
#   '33009',
#   'Broward'],
#  ['GTI (Rise Dispensaries)',
#   '4301 Alafaya Trail',
#   '-',
#   '-',
#   'Oviedo',
#   '32765',
#   'Seminole'],
#  ['GTI (Rise Dispensaries)',
#   '26701 S Tamiami Trail',
#   '-',
#   '-',
#   'Bonita Springs',
#   '33781',
#   'Lee'],
#  ['GTI (Rise Dispensaries)',
#   '6999 US Hwy 19',
#   '-',
#   '-',
#   'Pinellas Park',
#   '33781',
#   'Pinellas'],
#  ['GTI (Rise Dispensaries)',
#   '2305 W Hillsboro Boulevard',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33442',
#   'Broward'],
#  ['House of Platinum Cannabis',
#   '27062 US Hwy 19 N',
#   '-',
#   '-',
#   'Clearwater',
#   '33761',
#   'Pinellas'],
#  ['House of Platinum Cannabis',
#   '2832 4th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33704',
#   'Pinellas'],
#  ['House of Platinum Cannabis',
#   '1305 Beville Road',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32119',
#   'Volusia'],
#  ['House of Platinum Cannabis',
#   '10520 Spring Hill Drive',
#   '-',
#   '-',
#   'Spring Hill',
#   '34608',
#   'Hernando'],
#  ['Insa',
#   '10051 Skinner Lake Drive',
#   '-',
#   '-',
#   'Jacksonville',
#   '32246',
#   'Duval'],
#  ['Insa', '11220 SE 179th Place', '-', '-', 'Summerfield', '34491', 'Marion'],
#  ['Insa', '2650 E Bay Drive', '-', '-', 'Largo', '33771', 'Pinellas'],
#  ['Insa',
#   '702 U.S. Highway 27 S',
#   '-',
#   '-',
#   'Lake Placid',
#   '33852',
#   'Highlands'],
#  ['Insa', '12426 US Hwy 19', '-', '-', 'Hudson', '34667', 'Pasco'],
#  ['Insa', '7500 E Colonial Drive', '-', '-', 'Orlando', '32807', 'Orange'],
#  ['Insa', '640 W Tennessee Street', '-', '-', 'Tallahassee', '32304', 'Leon'],
#  ['Insa', '28540 US Highway 19 N', '-', '-', 'Clearwater', '33761', 'Pinellas'],
#  ['Insa',
#   '5115 S Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33611',
#   'Hillsborough'],
#  ['Jungle Boys',
#   '28751 S Tamiami Trail',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34134',
#   '-'],
#  ['Jungle Boys',
#   '1299 S Military Trail',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33442',
#   'Broward'],
#  ['Jungle Boys',
#   '6958 Collins Avenue',
#   '-',
#   '-',
#   'Miami Beach',
#   '33141',
#   'Miami-Dade'],
#  ['Jungle Boys',
#   '31650 US Hwy 19',
#   '-',
#   '-',
#   'Palm Harbor',
#   '34684',
#   'Pinellas'],
#  ['Jungle Boys',
#   '3495 NE 163rd Street',
#   '-',
#   '-',
#   'North Miami Beach',
#   '33160',
#   'Miami-Dade'],
#  ['Jungle Boys',
#   '1392 W International Speedway Boulevard',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Jungle Boys',
#   '11401 University Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32817',
#   'Orange'],
#  ['Jungle Boys', '2301 N Pine Avenue', '-', '-', 'Ocala', '34475', 'Marion'],
#  ['MuV', '4369 S Tamiami Trail', '-', '-', 'Venice', '34293', 'Sarasota'],
#  ['MuV', '1006 S US Hwy 1', '-', '-', 'Fort Pierce', '34950', 'St. Lucie'],
#  ['MuV', '9711 SW 77th Avenue', '-', '-', 'Miami', '33156', 'Miami-Dade'],
#  ['MuV', '5230 6th Street', '-', '-', 'Zephyrhills', '33542', 'Pasco'],
#  ['MuV',
#   '1315 Tuskawilla Road',
#   '-',
#   '-',
#   'Winter Springs',
#   '32708',
#   'Seminole'],
#  ['MuV',
#   '2550 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['MuV', '11247 E Colonial Drive', '-', '-', 'Orlando', '32817', 'Orange'],
#  ['MuV', '6883 Navarre Parkway', '-', '-', 'Navarre', '32566', 'Santa Rosa'],
#  ['MuV', '2938 W US Hwy 90', '-', '-', 'Lake City', '32055', 'Columbia'],
#  ['MuV',
#   '7915 Panama City Beach Parkway',
#   '-',
#   '-',
#   'Panama City Beach',
#   '32407',
#   'Bay'],
#  ['MuV', '3880 S Nova Road', '-', '-', 'Port Orange', '32127', 'Volusia'],
#  ['MuV', '2093 U.S. 92', '-', '-', 'Auburndale', '33823', 'Polk'],
#  ['MuV',
#   '4250 S Washington Avenue',
#   '-',
#   '-',
#   'Titusville',
#   '32780',
#   'Brevard'],
#  ['MuV', '725 Skymarks Drive', '-', '-', 'Jacksonville', '32218', 'Duval'],
#  ['MuV', '6661 Taft Street', '-', '-', 'Hollywood', '33024', 'Broward'],
#  ['MuV', '850 S Moody Road', '-', '-', 'Palatka', '32177', 'Putnam'],
#  ['MuV', '4820 S Himes Avenue', '-', '-', 'Tampa', '33611', 'Hillsborough'],
#  ['MuV',
#   '22627 Bayshore Road',
#   '-',
#   '-',
#   'Port Charlotte',
#   '33980',
#   'Charlotte'],
#  ['MuV', '7010 Cypress Terrace', '-', '-', 'Fort Myers', '33907', 'Lee'],
#  ['MuV', '1618 Main Street', '-', '-', 'Sarasota', '34236', 'Sarasota'],
#  ['MuV', '3900 US Hwy 27', '-', '-', 'Sebring', '33870', 'Highlands'],
#  ['MuV', '6580 N University Drive', '-', '-', 'Tamarac', '33319', 'Broward'],
#  ['MuV',
#   '6900 Cypress Gardens Boulevard',
#   '-',
#   '-',
#   'Winter Haven',
#   '33881',
#   'Polk'],
#  ['MuV', '3701 SW College Road', '-', '-', 'Ocala', '34474', 'Marion'],
#  ['MuV',
#   '11340 Summerlin Square Drive',
#   '-',
#   '-',
#   'Fort Myers',
#   '33907',
#   'Lee'],
#  ['MuV', '10455 SE Federal Highway', '-', '-', 'Hobe Sound', '33455', 'Martin'],
#  ['MuV', '695 Bald Eagle Drive', '-', '-', 'Marco Island', '34145', 'Collier'],
#  ['MuV',
#   '17521 Preserve Walk Lane',
#   '-',
#   '-',
#   'Tampa',
#   '33647',
#   'Hillsborough'],
#  ['MuV', '942 W Lumsden Rd', '-', '-', 'Brandon', '33511', 'Hillsborough'],
#  ['MuV', '265 SW Monterey Road', '-', '-', 'Stuart', '34994', 'Martin'],
#  ['MuV', '68 Blanding Boulevard', '-', '-', 'Orange Park', '32073', 'Clay'],
#  ['MuV',
#   '4450 W New Haven Avenue',
#   '-',
#   '-',
#   'West Melbourne',
#   '32904',
#   'Brevard'],
#  ['MuV',
#   '7263 Park Boulevard N',
#   '-',
#   '-',
#   'Pinellas Park',
#   '33781',
#   'Pinellas'],
#  ['MuV', '2494 Enterprise Road', '-', '-', 'Orange City', '32763', 'Volusia'],
#  ['MuV', '4312 75th Street W', '-', '-', 'Bradenton', '34209', 'Manatee'],
#  ['MuV',
#   '2617 W Kennedy Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33609',
#   'Hillsborough'],
#  ['MuV', '8103 Vineland Parkway', '-', '-', 'Orlando', '32821', 'Orange'],
#  ['MuV',
#   '18941 Old Shady Hills Road',
#   '-',
#   '-',
#   'Spring Hill',
#   '34610',
#   'Hernando'],
#  ['MuV',
#   '400 S Ponce De Leon Boulevard',
#   '-',
#   '-',
#   'St. Augustine',
#   '32084',
#   'St. Johns'],
#  ['MuV',
#   '929 N Courtenay Parkway',
#   '-',
#   '-',
#   'Merritt Island',
#   '32953',
#   'Brevard'],
#  ['MuV',
#   '5555 Roosevelt Boulevard',
#   '-',
#   '-',
#   'Clearwater',
#   '33760',
#   'Pinellas'],
#  ['MuV',
#   '137 E Woolbright Road',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33435',
#   'Palm Beach'],
#  ['MuV', '519 Duval Street', '-', '-', 'Key West', '33040', 'Monroe'],
#  ['MuV',
#   '2612 Santa Barbara Boulevard',
#   '-',
#   '-',
#   'Cape Coral',
#   '33914',
#   'Lee'],
#  ['MuV', '1246 Eglin Parkway', '-', '-', 'Shalimar', '32579', 'Okaloosa'],
#  ['MuV',
#   '120 SW Chamber Court',
#   '-',
#   '-',
#   'Port St. Lucie',
#   '34986',
#   'St. Lucie'],
#  ['MuV',
#   '313 Datura Street',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['MuV', '1101 1st Avenue N', '-', '-', 'St. Petersburg', '33705', 'Pinellas'],
#  ['MuV', '8465 Heritage Green Way', '-', '-', 'Bradenton', '34212', 'Manatee'],
#  ['MuV', '28245 S Tamiami Trail', '-', '-', 'Bonita Springs', '34134', 'Lee'],
#  ['MuV', '5674 Tuscola Boulevard', '-', '-', 'North Port', '34286', 'Sarasota'],
#  ['MuV', '929 US Hwy 441', '-', '-', 'Lady Lake', '32159', 'Lake'],
#  ['MuV',
#   '290 Clyde Morris Boulevard',
#   '-',
#   '-',
#   'Ormond Beach',
#   '32174',
#   'Volusia'],
#  ['MuV', '4785 N 9th Avenue', '-', '-', 'Pensacola', '32503', 'Escambia'],
#  ['MuV', '1701 US Hwy 1', '-', '-', 'Sebastian', '32958', 'Indian River'],
#  ['MuV', '21126 State Road 54', '-', '-', 'Lutz', '33558', 'Pasco'],
#  ['MuV', '2711 N Blairstone Road', '-', '-', 'Tallahassee', '32301', 'Leon'],
#  ['MuV',
#   '953 S Federal Highway',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['MuV', '101 S Garland Avenue', '-', '-', 'Orlando', '32801', 'Orange'],
#  ['MuV', '224 N Florida Avenue', '-', '-', 'Lakeland', '33801', 'Polk'],
#  ['MuV', '10993 Colonial Boulevard', '-', '-', 'Fort Myers', '33913', 'Lee'],
#  ['MuV', '1198 Beach Boulevard', '-', '-', 'Jacksonville', '32250', 'Duval'],
#  ['MuV', '2020 SW 34th Street', '-', '-', 'Gainesville', '32608', 'Alachua'],
#  ['MuV', '29901 US Hwy 19 N', '-', '-', 'Clearwater', '33761', 'Pinellas'],
#  ['MuV', '1550 Hendricks Avenue', '-', '-', 'Jacksonville', '32207', 'Duval'],
#  ['MuV', '1090 W State Road 434', '-', '-', 'Longwood', '32750', 'Seminole'],
#  ['MuV', '1045 State Road 7', '-', '-', 'Wellington', '33414', 'Palm Beach'],
#  ['MuV',
#   '7229 N Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33614',
#   'Hillsborough'],
#  ['MuV', '5045 Fruitville Road', '-', '-', 'Sarasota', '34232', 'Sarasota'],
#  ['MuV', '5909 US Hwy 41 N', '-', '-', 'Apollo Beach', '33572', 'Hillsborough'],
#  ['Sanctuary Cannabis',
#   '710 N Federal Highway',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33435',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '1260 Beville Road',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Sanctuary Cannabis',
#   '1310 NW 23rd Avenue',
#   '-',
#   '-',
#   'Gainesville',
#   '32605',
#   'Alachua'],
#  ['Sanctuary Cannabis',
#   '8345 SW 124th Street',
#   '-',
#   '-',
#   'Miami',
#   '33156',
#   'Miami-Dade'],
#  ['Sanctuary Cannabis',
#   '1070 Edgewood Avenue S',
#   '-',
#   '-',
#   'Jacksonville',
#   '32205',
#   'Duval'],
#  ['Sanctuary Cannabis',
#   '11450 Beach Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32246',
#   'Duval'],
#  ['Sanctuary Cannabis',
#   '21401 Powerline Road',
#   '-',
#   '-',
#   'Boca Raton',
#   '33433',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '5859 W Atlantic Avenue',
#   '-',
#   '-',
#   'Delray Beach',
#   '33484',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '839 S State Road 19',
#   '-',
#   '-',
#   'Palatka',
#   '32177',
#   'Putnam'],
#  ['Sanctuary Cannabis',
#   '877 E Palmetto Park Road',
#   '-',
#   '-',
#   'Boca Raton',
#   '33432',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '6905 Lake Worth Road',
#   '-',
#   '-',
#   'Greenacres',
#   '33467',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '6000 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33417',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '5712 W Waters Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33634',
#   'Hillsborough'],
#  ['Sanctuary Cannabis',
#   '1352 Main Street',
#   '-',
#   '-',
#   'Dunedin',
#   '34698',
#   'Pinellas'],
#  ['Sanctuary Cannabis',
#   '5001 S US Hwy 1',
#   '-',
#   '-',
#   'Fort Pierce',
#   '34982',
#   'St. Lucie'],
#  ['Sanctuary Cannabis',
#   '3790 Tyrone Boulevard N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33710',
#   'Pinellas'],
#  ['Sanctuary Cannabis',
#   '4208 US Hwy 27 S',
#   '-',
#   '-',
#   'Sebring',
#   '33870',
#   'Highlands'],
#  ['Sanctuary Cannabis',
#   '10064 W Indiantown Road',
#   '-',
#   '-',
#   'Jupiter',
#   '33478',
#   'Palm Beach'],
#  ['Sanctuary Cannabis',
#   '5381 International Drive',
#   '-',
#   '-',
#   'Orlando',
#   '32819',
#   'Orange'],
#  ['Sunburn',
#   '11190 San Jose Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32223',
#   'Duval'],
#  ['Sunburn', '130 Duval Street', '-', '-', 'Key West', '33040', 'Monroe'],
#  ['Sunburn', '1059 Park Street', '-', '-', 'Jacksonville', '32204', 'Duval'],
#  ['Sunburn', '1410 Main Street', '-', '-', 'Sarasota', '34236', 'Sarasota'],
#  ['Sunburn', '308 3rd Street S', '-', '-', 'Jacksonville', '32250', 'Duval'],
#  ['Sunburn', '1126 Thomasville Rd', '-', '-', 'Tallahassee', '32303', 'Leon'],
#  ['Sunburn',
#   '11551 University Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32817',
#   'Orange'],
#  ['Sunburn',
#   '2949 N Federal Highway',
#   '-',
#   '-',
#   'Fort Lauderdale',
#   '33306',
#   'Broward'],
#  ['Sunburn',
#   '326 5th Avenue N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33701',
#   'Pinellas'],
#  ['Sunburn',
#   '5048 Bayou Boulevard',
#   '-',
#   '-',
#   'Pensacola',
#   '32504',
#   'Escambia'],
#  ['Sunburn',
#   '539 Clematis Street',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['Sunnyside*',
#   '2725 College Street',
#   '-',
#   '-',
#   'Jacksonville',
#   '32205',
#   'Duval'],
#  ['Sunnyside*', '1260 Malabar Road', '-', '-', 'Palm Bay', '32907', 'Brevard'],
#  ['Sunnyside*',
#   '8123 4th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33702',
#   'Pinellas'],
#  ['Sunnyside*',
#   '661 Harbor Boulevard',
#   '-',
#   '-',
#   'Destin',
#   '32541',
#   'Okaloosa'],
#  ['Sunnyside*',
#   '8717 SW 24th Street',
#   '-',
#   '-',
#   'Miami',
#   '33165',
#   'Miami-Dade'],
#  ['Sunnyside*',
#   '35098 US Hwy 19 N',
#   '-',
#   '-',
#   'Palm Harbor',
#   '34684',
#   'Pinellas'],
#  ['Sunnyside*',
#   '6520 Lake Worth Road',
#   '-',
#   '-',
#   'Lake Worth',
#   '33467',
#   'Palm Beach'],
#  ['Sunnyside*',
#   '2051 Town Center Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32837',
#   'Orange'],
#  ['Sunnyside*',
#   '2710 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['Sunnyside*',
#   '591 S Semoran Boulevard',
#   '-',
#   '-',
#   'Winter Park',
#   '32792',
#   'Orange'],
#  ['Sunnyside*',
#   '2110 W International Speedway Boulevard',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Sunnyside*', '21708 State Road 54', '-', '-', 'Lutz', '33549', 'Pasco'],
#  ['Sunnyside*',
#   '6990 W Colonial Drive',
#   '-',
#   '-',
#   'Orlando',
#   '32818',
#   'Orange'],
#  ['Sunnyside*',
#   '2122 W 9 Mile Road',
#   '-',
#   '-',
#   'Pensacola',
#   '32534',
#   'Escambia'],
#  ['Sunnyside*',
#   '10916 Hutchison Boulevard',
#   '-',
#   '-',
#   'Panama City Beach',
#   '32407',
#   'Bay'],
#  ['Sunnyside*',
#   '1902 N Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33607',
#   'Hillsborough'],
#  ['Sunnyside*',
#   '1897 S Del Prado Boulevard',
#   '-',
#   '-',
#   'Cape Coral',
#   '33990',
#   'Lee'],
#  ['Sunnyside*', '415 US Hwy 441', '-', '-', 'Lady Lake', '32159', 'Lake'],
#  ['Sunnyside*',
#   '19042 US Hwy 19 N',
#   '-',
#   '-',
#   'Clearwater',
#   '33764',
#   'Pinellas'],
#  ['Sunnyside*',
#   '8307 Lockwood Ridge Road',
#   '-',
#   '-',
#   'Sarasota',
#   '34243',
#   'Sarasota'],
#  ['Sunnyside*',
#   '3900 N 9th Avenue',
#   '-',
#   '-',
#   'Pensacola',
#   '32503',
#   'Escambia'],
#  ['Sunnyside*',
#   '505 NE 125th Street',
#   '-',
#   '-',
#   'North Miami',
#   '33161',
#   'Miami-Dade'],
#  ['Sunnyside*',
#   '302 N Monroe Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32301',
#   'Leon'],
#  ['Sunnyside*',
#   '499 E Oakland Park',
#   '-',
#   '-',
#   'Oakland Park',
#   '33334',
#   'Broward'],
#  ['Sunnyside*',
#   '1830 Cordova Road',
#   '-',
#   '-',
#   'Fort Lauderdale',
#   '33316',
#   'Broward'],
#  ['Sunnyside*',
#   '18500 Bonita Crossings Boulevard',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Sunnyside*',
#   '134 Fernwood Boulevard',
#   '-',
#   '-',
#   'Fern Park',
#   '32730',
#   'Seminole'],
#  ['Sunnyside*', '299 US Hwy 27 S', '-', '-', 'Avon Park', '33825', 'Highlands'],
#  ['Sunnyside*', '811 NE 36th Avenue', '-', '-', 'Ocala', '32270', 'Marion'],
#  ['Sunnyside*',
#   '7510 US Hwy 1',
#   '-',
#   '-',
#   'Port St. Lucie',
#   '34952',
#   'St. Lucie'],
#  ['Sunnyside*',
#   '150 22nd Street',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33712',
#   'Pinellas'],
#  ['Sunnyside*',
#   '1161 Beach Boulevard',
#   '-',
#   '-',
#   'Jacksonville Beach',
#   '32250',
#   'Duval'],
#  ['Sunnyside*',
#   '202 E Boynton Beach Boulevard',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33435',
#   'Palm Beach'],
#  ['Surterra Wellness',
#   '1531 Alton Court',
#   '-',
#   '-',
#   'Miami Beach',
#   '33139',
#   'Miami-Dade'],
#  ['Surterra Wellness',
#   '2820 E Colonial Drive',
#   '-',
#   '-',
#   'Orlando',
#   '32803',
#   'Orange'],
#  ['Surterra Wellness',
#   '10755 SW 72nd St',
#   '-',
#   '-',
#   'Miami',
#   '33173',
#   'Miami-Dade'],
#  ['Surterra Wellness',
#   '1776 E Sunrise Boulevard',
#   '-',
#   '-',
#   'Fort Lauderdale',
#   '33304',
#   'Broward'],
#  ['Surterra Wellness',
#   '1495 State Road 50 E',
#   '-',
#   '-',
#   'Clermont',
#   '34711',
#   'Lake'],
#  ['Surterra Wellness',
#   '1300 US 27',
#   '-',
#   '-',
#   'Avon Park',
#   '33825',
#   'Highlands'],
#  ['Surterra Wellness',
#   '2573 S Ferdon Boulevard',
#   '-',
#   '-',
#   'Crestview',
#   '32539',
#   'Okaloosa'],
#  ['Surterra Wellness',
#   '13642 Atlantic Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32225',
#   'Duval'],
#  ['Surterra Wellness',
#   '697 S Federal Highway',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['Surterra Wellness',
#   '100 Flagler Plaza Drive',
#   '-',
#   '-',
#   'Palm Coast',
#   '32137',
#   'Flagler'],
#  ['Surterra Wellness',
#   '3050 Alafaya Trail',
#   '-',
#   '-',
#   'Oviedo',
#   '32765',
#   'Seminole'],
#  ['Surterra Wellness',
#   '2500 S Dixie Highway',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33401',
#   'Palm Beach'],
#  ['Surterra Wellness',
#   '233 Racetrack Road NW',
#   '-',
#   '-',
#   'Fort Walton',
#   '32547',
#   'Okaloosa'],
#  ['Surterra Wellness',
#   '3975 W Boynton Beach Boulevard',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33436',
#   'Palm Beach'],
#  ['Surterra Wellness',
#   '745 S Broad Street',
#   '-',
#   '-',
#   'Brooksville',
#   '34601',
#   'Hernando'],
#  ['Surterra Wellness',
#   '324 E Merritt Island Causeway',
#   '-',
#   '-',
#   'Merritt Island',
#   '32952',
#   'Brevard'],
#  ['Surterra Wellness',
#   '6815 53rd Avenue',
#   '-',
#   '-',
#   'Bradenton',
#   '34203',
#   'Manatee'],
#  ['Surterra Wellness',
#   '15 SW 1st Avenue',
#   '-',
#   '-',
#   'Gainesville',
#   '32601',
#   'Alachua'],
#  ['Surterra Wellness',
#   '12720 McGregor Boulevard',
#   '-',
#   '-',
#   'Fort Myers',
#   '33919',
#   'Lee'],
#  ['Surterra Wellness',
#   '10915 SE 174th Place',
#   '-',
#   '-',
#   'Summerfield',
#   '34491',
#   'Marion'],
#  ['Surterra Wellness',
#   '514 Cypress Gardens Boulevard',
#   '-',
#   '-',
#   'Winter Haven',
#   '33880',
#   'Polk'],
#  ['Surterra Wellness',
#   '411 E 23rd Street',
#   '-',
#   '-',
#   'Panama City',
#   '32405',
#   'Bay'],
#  ['Surterra Wellness',
#   '15200 S Jog Road',
#   '-',
#   '-',
#   'Delray Beach',
#   '33446',
#   'Palm Beach'],
#  ['Surterra Wellness',
#   '6647 S Dixie Highway',
#   '-',
#   '-',
#   'Miami',
#   '33143',
#   'Miami-Dade'],
#  ['Surterra Wellness',
#   '3126 Flagler Avenue',
#   '-',
#   '-',
#   'Key West',
#   '33040',
#   'Monroe'],
#  ['Surterra Wellness',
#   '4306 S Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33611',
#   'Hillsborough'],
#  ['Surterra Wellness',
#   '1256 E Brandon Boulevard',
#   '-',
#   '-',
#   'Brandon',
#   '33511',
#   'Hillsborough'],
#  ['Surterra Wellness',
#   '28520 Bonita Crossings Boulevard',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Surterra Wellness',
#   '7061 US Hwy 1',
#   '-',
#   '-',
#   'Port St. Lucie',
#   '34952',
#   'St. Lucie'],
#  ['Surterra Wellness',
#   '11115 SW 93rd Court Road',
#   '-',
#   '-',
#   'Ocala',
#   '34481',
#   'Marion'],
#  ['Surterra Wellness',
#   '4218 US Hwy 19',
#   '-',
#   '-',
#   'New Port Richey',
#   '34652',
#   'Pasco'],
#  ['Surterra Wellness',
#   '1222 Florida Avenue S',
#   '-',
#   '-',
#   'Lakeland',
#   '33801',
#   'Polk'],
#  ['Surterra Wellness',
#   '11575 US Hwy 1',
#   '-',
#   '-',
#   'North Palm Beach',
#   '33408',
#   'Palm Beach'],
#  ['Surterra Wellness',
#   '6295 Minton Road NE',
#   '-',
#   '-',
#   'Palm Bay',
#   '32907',
#   'Brevard'],
#  ['Surterra Wellness',
#   '2001 4th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33704',
#   'Pinellas'],
#  ['Surterra Wellness',
#   '80 Blanding Boulevard',
#   '-',
#   '-',
#   'Orange Park',
#   '32073',
#   'Clay'],
#  ['Surterra Wellness',
#   '3665 S Clyde Morris Boulevard',
#   '-',
#   '-',
#   'Port Orange',
#   '32129',
#   'Volusia'],
#  ['Surterra Wellness',
#   '537 Park Street',
#   '-',
#   '-',
#   'Jacksonville',
#   '32204',
#   'Duval'],
#  ['Surterra Wellness',
#   '2558 E Fowler Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33612',
#   'Hillsborough'],
#  ['Surterra Wellness',
#   '1639 Village Square Boulevard',
#   '-',
#   '-',
#   'Tallahassee',
#   '32309',
#   'Leon'],
#  ['Surterra Wellness',
#   '5046 Bayou Boulevard',
#   '-',
#   '-',
#   'Pensacola',
#   '32503',
#   'Escambia'],
#  ['Surterra Wellness',
#   '1743 S Orange Avenue',
#   '-',
#   '-',
#   'Orlando',
#   '32806',
#   'Orange'],
#  ['Surterra Wellness',
#   '14906 Tamiami Trail',
#   '-',
#   '-',
#   'North Port',
#   '34287',
#   'Sarasota'],
#  ['Surterra Wellness',
#   '10761 Ulmerton Road',
#   '-',
#   '-',
#   'Largo',
#   '33771',
#   'Pinellas'],
#  ['Surterra Wellness',
#   '1200 Deltona Boulevard',
#   '-',
#   '-',
#   'Deltona',
#   '32725',
#   'Volusia'],
#  ['The Flowery', '1704 S Pine Avenue', '-', '-', 'Ocala', '34471', 'Marion'],
#  ['The Flowery',
#   '1201 N Highland Avenue',
#   '-',
#   '-',
#   'Clearwater',
#   '33755',
#   'Pinellas'],
#  ['The Flowery',
#   '8669 Baymeadows Road',
#   '-',
#   '-',
#   'Jacksonville',
#   '32256',
#   'Duval'],
#  ['The Flowery',
#   '3129 E Gulf Lake Highway',
#   '-',
#   '-',
#   'Inverness',
#   '34453',
#   'Citrus'],
#  ['The Flowery',
#   '11900 Biscayne Boulevard',
#   '-',
#   '-',
#   'Miami',
#   '33181',
#   'Miami-Dade'],
#  ['Trulieve',
#   '2647 E Irlo Bronson Memorial Hwy',
#   '-',
#   '-',
#   'Kissimmee',
#   '34744',
#   'Osceola'],
#  ['Trulieve',
#   '5660 Bayshore Road',
#   '-',
#   '-',
#   'North Fort Myers',
#   '33917',
#   'Lee'],
#  ['Trulieve',
#   '1011 5th Street',
#   '-',
#   '-',
#   'Miami Beach',
#   '33139',
#   'Miami-Dade'],
#  ['Trulieve', '101 Hwy 17', '-', '-', 'Palatka', '32177', 'Putnam'],
#  ['Trulieve',
#   '6000 Cypress Gardens Boulevard',
#   '-',
#   '-',
#   'Winter Haven',
#   '33884',
#   'Polk'],
#  ['Trulieve',
#   '10835 SE Federal Highway',
#   '-',
#   '-',
#   'Hobe Sound',
#   '33455',
#   'Martin'],
#  ['Trulieve',
#   '8724 Lake Worth Road',
#   '-',
#   '-',
#   'Lake Worth',
#   '33467',
#   'Palm Beach'],
#  ['Trulieve',
#   '17704 Aprile Drive',
#   '-',
#   '-',
#   "Land O' Lakes",
#   '34638',
#   'Pasco'],
#  ['Trulieve',
#   '2102 S Ridgewood Avenue',
#   '-',
#   '-',
#   'Edgewater',
#   '32141',
#   'Volusia'],
#  ['Trulieve', '2005 Hwy 92 W', '-', '-', 'Auburndale', '33823', 'Polk'],
#  ['Trulieve',
#   '51 N Doverplum Avenue',
#   '-',
#   '-',
#   'Poinciana',
#   '33020',
#   'Osceola'],
#  ['Trulieve',
#   '2121 W Orange Blossom Trail',
#   '-',
#   '-',
#   'Apopka',
#   '33823',
#   'Orange'],
#  ['Trulieve',
#   '2908 Hollywood Boulevard',
#   '-',
#   '-',
#   'Hollywood',
#   '33020',
#   'Broward'],
#  ['Trulieve',
#   '10400 W Atlantic Boulevard',
#   '-',
#   '-',
#   'Coral Springs',
#   '33071',
#   'Broward'],
#  ['Trulieve', '5422 US Hwy 19', '-', '-', 'Port Richey', '34652', 'Pasco'],
#  ['Trulieve', '6601 Gall Boulevard', '-', '-', 'Zephyrhills', '33542', 'Pasco'],
#  ['Trulieve', '15620 Summerlin Road', '-', '-', 'Fort Myers', '33908', 'Lee'],
#  ['Trulieve',
#   '23233 S State Road 7',
#   '-',
#   '-',
#   'Boca Raton',
#   '33428',
#   'Palm Beach'],
#  ['Trulieve',
#   '10113 Gibsonton Drive',
#   '-',
#   '-',
#   'Riverview',
#   '33578',
#   'Hillsborough'],
#  ['Trulieve', '10523 US Hwy 19', '-', '-', 'Port Richey', '34668', 'Pasco'],
#  ['Trulieve',
#   '7702 E Hillsborough Avenue',
#   '-',
#   '-',
#   'Tampa',
#   '33610',
#   'Hillsborough'],
#  ['Trulieve',
#   '1300 N Parrott Avenue',
#   '-',
#   '-',
#   'Okeechobee',
#   '34972',
#   'Okeechobee'],
#  ['Trulieve',
#   '8602 N Dale Mabry Highway',
#   '-',
#   '-',
#   'Tampa',
#   '33614',
#   'Hillsborough'],
#  ['Trulieve', '6722 14th Street W', '-', '-', 'Bradenton', '34207', 'Manatee'],
#  ['Trulieve', '950 W Main Street', '-', '-', 'Inverness', '34450', 'Citrus'],
#  ['Trulieve', '1030 Broadway Avenue N', '-', '-', 'Bartow', '33830', 'Polk'],
#  ['Trulieve',
#   '19300 S Dixie Highway',
#   '-',
#   '-',
#   'Cutler Bay',
#   '33157',
#   'Miami-Dade'],
#  ['Trulieve',
#   '1068 SE Port Saint Lucie Boulevard',
#   '-',
#   '-',
#   'Port Saint Lucie',
#   '34952',
#   'Saint Lucie'],
#  ['Trulieve', '1650 US Hwy 1', '-', '-', 'St. Augustine', '32084', 'St. Johns'],
#  ['Trulieve',
#   '330 Winchester Park Boulevard',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33436',
#   'Palm Beach'],
#  ['Trulieve',
#   '7505 Red Bug Lake Road',
#   '-',
#   '-',
#   'Oviedo',
#   '32765',
#   'Seminole'],
#  ['Trulieve',
#   '10339 San Jose Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32257',
#   'Duval'],
#  ['Trulieve',
#   '1090 Dunlawton Avenue',
#   '-',
#   '-',
#   'Port Orange',
#   '32127',
#   'Volusia'],
#  ['Trulieve',
#   '106 W N Boulevard, Suite 105',
#   '-',
#   '-',
#   'Leesburg',
#   '34748',
#   'Lake'],
#  ['Trulieve', '275 NE US Hwy 19', '-', '-', 'Crystal River', '34429', 'Citrus'],
#  ['Trulieve', '749 3rd Street NW', '-', '-', 'Winter Haven', '33881', 'Polk'],
#  ['Trulieve',
#   '15100 Biscayne Boulevard',
#   '-',
#   '-',
#   'North Miami Beach',
#   '33160',
#   'Miami-Dade'],
#  ['Trulieve', '8640 Aloma Avenue', '-', '-', 'Winter Park', '32792', 'Orange'],
#  ['Trulieve',
#   '1315 Homestead Road N',
#   '-',
#   '-',
#   'Lehigh Acres',
#   '33936',
#   'Lee'],
#  ['Trulieve',
#   '91216 Overseas Highway',
#   '-',
#   '-',
#   'Tavernier',
#   '33070',
#   'Monroe'],
#  ['Trulieve',
#   '8625 Citrus Park Drive',
#   '-',
#   '-',
#   'Tampa',
#   '33625',
#   'Hillsborough'],
#  ['Trulieve', '1100 S Tamiami Trail', '-', '-', 'Osprey', '34229', 'Sarasota'],
#  ['Trulieve',
#   '9578 Bird Road',
#   '-',
#   '-',
#   'Olympia Heights',
#   '33165',
#   'Miami-Dade'],
#  ['Trulieve',
#   '4139 Okeechobee Boulevard',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['Trulieve', '2901 S Bay Street', '-', '-', 'Eustis', '32726', 'Lake'],
#  ['Trulieve',
#   '3555 Northlake Boulevard',
#   '-',
#   '-',
#   'Palm Beach Gardens',
#   '33403',
#   'Palm Beach'],
#  ['Trulieve', '1846 Main Street', '-', '-', 'Dunedin', '34698', 'Pinellas'],
#  ['Trulieve', '2058 US Hwy 27 N', '-', '-', 'Sebring', '33870', 'Highlands'],
#  ['Trulieve',
#   '3126 W Gandy Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33611',
#   'Hillsborough'],
#  ['Trulieve', '5900 Rock Island Road', '-', '-', 'Tamarac', '33319', 'Broward'],
#  ['Trulieve',
#   '2794 Gulf to Bay Boulevard',
#   '-',
#   '-',
#   'Clearwater',
#   '33759',
#   'Pinellas'],
#  ['Trulieve',
#   '8355 Baymeadows Road',
#   '-',
#   '-',
#   'Jacksonville',
#   '32256',
#   'Duval'],
#  ['Trulieve', '1621 US Hwy 1', '-', '-', 'Sebastian', '32958', 'Indian River'],
#  ['Trulieve', '17950 US Hwy 441', '-', '-', 'Summerfield', '34491', 'Marion'],
#  ['Trulieve',
#   '1614 W University Avenue',
#   '-',
#   '-',
#   'Gainesville',
#   '32603',
#   'Alachua'],
#  ['Trulieve',
#   '2500 Deer Creek Commerce Lane',
#   '-',
#   '-',
#   'Davenport',
#   '33837',
#   'Polk'],
#  ['Trulieve',
#   '801 W Martin Luther King Jr Boulevard',
#   '-',
#   '-',
#   'Seffner',
#   '33584',
#   'Hillsborough'],
#  ['Trulieve', '17011 State Road 50', '-', '-', 'Clermont', '34711', 'Lake'],
#  ['Trulieve', '2670 W US Hwy 90', '-', '-', 'Lake City', '32055', 'Columbia'],
#  ['Trulieve',
#   '2616 Enterprise Road',
#   '-',
#   '-',
#   'Orange City',
#   '32763',
#   'Volusia'],
#  ['Trulieve',
#   '638 Oakfield Drive',
#   '-',
#   '-',
#   'Brandon',
#   '33511',
#   'Hillsborough'],
#  ['Trulieve',
#   '10175 Tamiami Trail',
#   '-',
#   '-',
#   'Punta Gorda',
#   '33950',
#   'Charlotte'],
#  ['Trulieve', '4808 Manatee Ave W', '-', '-', 'Bradenton', '34209', 'Manatee'],
#  ['Trulieve', '30600 US Hwy 19', '-', '-', 'Palm Harbor', '34684', 'Pinellas'],
#  ['Trulieve',
#   '15140 Jog Road',
#   '-',
#   '-',
#   'Delray Beach',
#   '33446',
#   'Palm Beach'],
#  ['Trulieve',
#   '700 E Merritt Island Causeway',
#   '-',
#   '-',
#   'Merritt Island',
#   '32952',
#   'Brevard'],
#  ['Trulieve', '12575 S Cleveland Ave', '-', '-', 'Fort Myers', '33907', 'Lee'],
#  ['Trulieve',
#   '4410 W Hillsborough Ave',
#   '-',
#   '-',
#   'Tampa',
#   '33614',
#   'Hillsborough'],
#  ['Trulieve',
#   '6752 22nd Avenue N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33710',
#   'Pinellas'],
#  ['Trulieve',
#   '820 W State Road 434',
#   '-',
#   '-',
#   'Longwood',
#   '32750',
#   'Seminole'],
#  ['Trulieve',
#   '2916 E Busch Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33612',
#   'Hillsborough'],
#  ['Trulieve', '1720 S McCall Road', '-', '-', 'Englewood', '34223', 'Sarasota'],
#  ['Trulieve',
#   '40545 US Hwy 19 N',
#   '-',
#   '-',
#   'Tarpon Springs',
#   '34689',
#   'Pinellas'],
#  ['Trulieve',
#   '1288 SW Gatlin Blvd',
#   '-',
#   '-',
#   'Port St. Lucie',
#   '34953',
#   'St. Lucie'],
#  ['Trulieve', '1495 S US Hwy 1', '-', '-', 'Fort Pierce', '34950', 'St. Lucie'],
#  ['Trulieve',
#   '14099 Cortez Boulevard',
#   '-',
#   '-',
#   'Brooksville',
#   '34613',
#   'Hernando'],
#  ['Trulieve', '1927 SW College Road', '-', '-', 'Ocala', '34471', 'Marion'],
#  ['Trulieve',
#   '812 W International Speedway',
#   '-',
#   '-',
#   'Daytona Beach',
#   '32114',
#   'Volusia'],
#  ['Trulieve', '4192 Conroy Road', '-', '-', 'Orlando', '32839', 'Orange'],
#  ['Trulieve',
#   '3055 Columbia Boulevard',
#   '-',
#   '-',
#   'Titusville',
#   '32780',
#   'Brevard'],
#  ['Trulieve', '1970 NW Federal Highway', '-', '-', 'Stuart', '34994', 'Martin'],
#  ['Trulieve',
#   '1901 E Nine Mile Road',
#   '-',
#   '-',
#   'Pensacola',
#   '32514',
#   'Escambia'],
#  ['Trulieve',
#   '418 Mary Esther Cut Off NW',
#   '-',
#   '-',
#   'Fort Walton Beach',
#   '32548',
#   'Okaloosa'],
#  ['Trulieve',
#   '342 Blanding Boulevard',
#   '-',
#   '-',
#   'Orange Park',
#   '32073',
#   'Clay'],
#  ['Trulieve', '11291 E Colonial Drive', '-', '-', 'Orlando', '32817', 'Orange'],
#  ['Trulieve', '1644 N Florida Avenue', '-', '-', 'Lakeland', '33805', 'Polk'],
#  ['Trulieve',
#   '27437 Wesley Chapel Boulevard',
#   '-',
#   '-',
#   'Wesley Chapel',
#   '33544',
#   'Pasco'],
#  ['Trulieve',
#   '9952 Hutchison Boulevard',
#   '-',
#   '-',
#   'Panama City Beach',
#   '32407',
#   'Bay'],
#  ['Trulieve',
#   '2517 Santa Barbara Boulevard',
#   '-',
#   '-',
#   'Cape Coral',
#   '33914',
#   'Lee'],
#  ['Trulieve', '862 US Hwy 98 E', '-', '-', 'Destin', '32541', 'Okaloosa'],
#  ['Trulieve',
#   '2076 Seminole Boulevard',
#   '-',
#   '-',
#   'Largo',
#   '33778',
#   'Pinellas'],
#  ['Trulieve',
#   '102 N 6th Avenue',
#   '-',
#   '-',
#   'Jacksonville Beach',
#   '32250',
#   'Duval'],
#  ['Trulieve', '400 Duval Street', '-', '-', 'Key West', '33040', 'Monroe'],
#  ['Trulieve',
#   '4120 Tamiami Trail',
#   '-',
#   '-',
#   'Port Charlotte',
#   '33952',
#   'Charlotte'],
#  ['Trulieve',
#   '645 Bayway Boulevard',
#   '-',
#   '-',
#   'Clearwater',
#   '33767',
#   'Pinellas'],
#  ['Trulieve', '3833 Archer Road', '-', '-', 'Gainesville', '32608', 'Alachua'],
#  ['Trulieve',
#   '474285 E State Road 200',
#   '-',
#   '-',
#   'Fernandina Beach',
#   '32034',
#   'Nassau'],
#  ['Trulieve',
#   '9521 S Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32712',
#   'Orange'],
#  ['Trulieve',
#   '1417 SW 40th Terrace',
#   '-',
#   '-',
#   'Fort Lauderdale',
#   '33317',
#   'Broward'],
#  ['Trulieve',
#   '10095 Beach Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32246',
#   'Duval'],
#  ['Trulieve',
#   '10347 Bonita Beach Road SE',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34135',
#   'Lee'],
#  ['Trulieve',
#   '7050 Sumter Crossing Drive',
#   '-',
#   '-',
#   'North Port',
#   '34287',
#   'Sarasota'],
#  ['Trulieve',
#   '182 W State Road 434',
#   '-',
#   '-',
#   'Longwood',
#   '32750',
#   'Seminole'],
#  ['Trulieve',
#   '1800 W Tennessee Street',
#   '-',
#   '-',
#   'Tallahassee',
#   '32304',
#   'Leon'],
#  ['Trulieve',
#   '3330 W New Haven Avenue',
#   '-',
#   '-',
#   'Melbourne',
#   '32904',
#   'Brevard'],
#  ['Trulieve', '18350 NW 47th Avenue', '-', '-', 'Miami', '33055', 'Miami-Dade'],
#  ['Trulieve', '24639 US Hwy 19 N', '-', '-', 'Clearwater', '33763', 'Pinellas'],
#  ['Trulieve',
#   '4967 W Irlo Bronson Memorial Highway',
#   '-',
#   '-',
#   'Kissimmee',
#   '34746',
#   'Osceola'],
#  ['Trulieve',
#   '1260 Jacaranda Boulevard',
#   '-',
#   '-',
#   'Venice',
#   '34292',
#   'Sarasota'],
#  ['Trulieve',
#   '1324 N Military Trail',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['Trulieve',
#   '458 W Hillsboro Boulevard',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33441',
#   'Broward'],
#  ['Trulieve', '935 N Beneva Road', '-', '-', 'Sarasota', '34232', 'Sarasota'],
#  ['Trulieve', '520 Stirling Road', '-', '-', 'Dania Beach', '33004', 'Broward'],
#  ['Trulieve',
#   '1534 SW 8th Street',
#   '-',
#   '-',
#   'Boynton Beach',
#   '33426',
#   'Palm Beach'],
#  ['Trulieve',
#   '28 Old Kings Road N',
#   '-',
#   '-',
#   'Palm Coast',
#   '32137',
#   'Flagler'],
#  ['Trulieve', '9600 SW 77th Avenue', '-', '-', 'Miami', '33156', 'Miami-Dade'],
#  ['Trulieve',
#   '1814 Commerce Avenue',
#   '-',
#   '-',
#   'Vero Beach',
#   '32960',
#   'Indian River'],
#  ['Trulieve',
#   '800 Capital Circle SE',
#   '-',
#   '-',
#   'Tallahassee',
#   '32301',
#   'Leon'],
#  ['Trulieve',
#   '8435 4th Street N',
#   '-',
#   '-',
#   'St. Petersburg',
#   '33702',
#   'Pinellas'],
#  ['Trulieve',
#   '3119 N Davis Highway',
#   '-',
#   '-',
#   'Pensacola',
#   '32503',
#   'Escambia'],
#  ['Trulieve',
#   '4544 N Orange Blossom Trail',
#   '-',
#   '-',
#   'Orlando',
#   '32804',
#   'Orange'],
#  ['Trulieve', '4020 NW 26th Street', '-', '-', 'Miami', '33142', 'Miami-Dade'],
#  ['Trulieve', '13940 US Hwy 441', '-', '-', 'Lady Lake', '32159', 'Sumter'],
#  ['Trulieve',
#   '6259 Beach Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32216',
#   'Duval'],
#  ['Trulieve',
#   '1527 NW 6th Street',
#   '-',
#   '-',
#   'Gainesville',
#   '32601',
#   'Alachua'],
#  ['Trulieve',
#   '13971 N Cleveland Avenue',
#   '-',
#   '-',
#   'Fort Myers',
#   '33903',
#   'Lee'],
#  ['VidaCann',
#   '17350 SE 109th Terrace Road',
#   '-',
#   '-',
#   'Summerfield',
#   '34491',
#   'Marion'],
#  ['VidaCann',
#   '5850 Sunset Drive',
#   '-',
#   '-',
#   'South Miami',
#   '33143',
#   'Miami-Dade'],
#  ['VidaCann',
#   '2881 N Military Trail',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33409',
#   'Palm Beach'],
#  ['VidaCann', '2560 FL-50', '-', '-', 'Orlando', '34711', 'Orange'],
#  ['VidaCann',
#   '11610 Emerald Coast Parkway',
#   '-',
#   '-',
#   'Miramar Beach',
#   '32550',
#   'Walton'],
#  ['VidaCann', '4000 Hwy 98 N', '-', '-', 'Lakeland', '33809', 'Polk'],
#  ['VidaCann',
#   '12955 Seminole Boulevard',
#   '-',
#   '-',
#   'Largo',
#   '33778',
#   'Pinellas'],
#  ['VidaCann',
#   '17631 Bruce B Down Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33647',
#   'Hillsborough'],
#  ['VidaCann',
#   '11099 Biscayne Boulevard',
#   '-',
#   '-',
#   'Miami',
#   '33161',
#   'Miami-Dade'],
#  ['VidaCann',
#   '4339 Roosevelt Boulevard',
#   '-',
#   '-',
#   'Jacksonville',
#   '32210',
#   'Duval'],
#  ['VidaCann', '1655 NW Federal Highway', '-', '-', 'Stuart', '34994', 'Martin'],
#  ['VidaCann',
#   '1411 Cape Coral Parkway E',
#   '-',
#   '-',
#   'Cape Coral',
#   '33904',
#   'Lee'],
#  ['VidaCann',
#   '3607 SW Archer Road',
#   '-',
#   '-',
#   'Gainesville',
#   '32608',
#   'Alachua'],
#  ['VidaCann',
#   '7400 Southland Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32809',
#   'Orange'],
#  ['VidaCann',
#   '770 S Military Trail',
#   '-',
#   '-',
#   'West Palm Beach',
#   '33415',
#   'Palm Beach'],
#  ['VidaCann',
#   '2401 Langley Avenue',
#   '-',
#   '-',
#   'Pensacola',
#   '32504',
#   'Escambia'],
#  ['VidaCann', '5298 Sunbeam Road', '-', '-', 'Jacksonville', '32257', 'Duval'],
#  ['VidaCann',
#   '26251 S Tamiami Trail',
#   '-',
#   '-',
#   'Bonita Springs',
#   '34134',
#   'Lee'],
#  ['VidaCann',
#   '1100 El Jobean Road',
#   '-',
#   '-',
#   'Port Charlotte',
#   '33948',
#   'Charlotte'],
#  ['VidaCann', '1212 N Monroe Street', '-', '-', 'Tallahassee', '32303', 'Leon'],
#  ['VidaCann',
#   '1700 N Semoran Boulevard',
#   '-',
#   '-',
#   'Orlando',
#   '32807',
#   'Orange'],
#  ['VidaCann',
#   '2007 W Kennedy Boulevard',
#   '-',
#   '-',
#   'Tampa',
#   '33606',
#   'Hillsborough'],
#  ['VidaCann', '5203 Cortez Road W', '-', '-', 'Bradenton', '34210', 'Manatee'],
#  ['VidaCann',
#   '1101 S Powerline Road',
#   '-',
#   '-',
#   'Deerfield Beach',
#   '33442',
#   'Broward'],
#  ['VidaCann',
#   '1663 Georgia Street NE',
#   '-',
#   '-',
#   'Palm Bay',
#   '32907',
#   'Brevard'],
#  ['VidaCann', '1027 N Nova Road', '-', '-', 'Holly Hill', '32117', 'Volusia']]

# %%
# import data into a dataframe

df_locations = pd.DataFrame(row_data, columns=header_names)

df_locations
# Out:
#                      COMPANY                         ADDRESS EMAIL ADDRESS  \
# 0    Ayr Cannabis Dispensary     6325 N Orange Blossom Trail             -
# 1    Ayr Cannabis Dispensary               7390 Aloma Avenue             -
# 2    Ayr Cannabis Dispensary            4650 N Alafaya Trail             -
# 3    Ayr Cannabis Dispensary             440 N State Road 19             -
# 4    Ayr Cannabis Dispensary  6930 Cypress Gardens Boulevard             -
# ..                       ...                             ...           ...
# 584                 VidaCann        2007 W Kennedy Boulevard             -
# 585                 VidaCann              5203 Cortez Road W             -
# 586                 VidaCann           1101 S Powerline Road             -
# 587                 VidaCann          1663 Georgia Street NE             -
# 588                 VidaCann                1027 N Nova Road             -
#
#     PHONE             CITY ZIP CODE        COUNTY
# 0       -          Orlando    32810        Orange
# 1       -      Winter Park    32792        Orange
# 2       -          Orlando    32826        Orange
# 3       -          Palatka    32177        Putnam
# 4       -     Winter Haven    33884          Polk
# ..    ...              ...      ...           ...
# 584     -            Tampa    33606  Hillsborough
# 585     -        Bradenton    34210       Manatee
# 586     -  Deerfield Beach    33442       Broward
# 587     -         Palm Bay    32907       Brevard
# 588     -       Holly Hill    32117       Volusia
#
# [589 rows x 7 columns]

# %%
browser.quit()

# %%
# export df

df_companies_path = 'exports/df_companies.csv'
df_locations_path = 'exports/df_locations.csv'

df_companies.to_csv(df_companies_path, index=False)
df_locations.to_csv(df_locations_path, index=False)
